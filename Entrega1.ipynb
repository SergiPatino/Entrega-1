# %% [markdown]
# <a href="https://colab.research.google.com/github/SergiPatino/Entrega-1/blob/main/Entrega1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def funcio(u):
   f = np.sin(u)
   g = np.cos(u)
   h = np.tan(u)
   return f,g,h

# %%
x = np.arange(0, 2*np.pi, 0.1)

# %%
f,g,h = funcio(x)

# %%
plt.plot(x, f, 'r', x, g, 'b', x, h, 'g')
plt.plot(x, f, 'ro', x, g, 'bo', x, h, 'go')
plt.xlabel('Valors de x')
plt.ylabel('Valors de y')
plt.title('Representació de y=cos(x), y=sin(x) i y=tan(x)')
plt.legend(['sin(x)', 'cos(x)','tan(x)'])
plt.grid(True)
plt.ylim((-5,5))
plt.show()
